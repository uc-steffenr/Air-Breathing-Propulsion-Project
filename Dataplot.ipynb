# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.interpolate import interp1d


x = [1,2,3] #stages
# a1 = [0,-80.7743,23.1328]
# a2 = [53.4752,15.7453,80.4371]
# a3 = [-80.7743,23.1328,-45.8553]
# b2 = [37.7160,40.0303,42.1975]
# b3 = [64.6071,63.8861,63.1261]
PR = [0.7398101212389925,0.7232052988627009,0.7043616179899845]


fig,ax = plt.subplots()
# ax.plot(x,a1,label='a1')
# ax.plot(x,a2,label='a2')
# ax.plot(x,a3,label='a3')
# ax.plot(x,b2,label='b2')
# ax.plot(x,b3,label='b3')
ax.plot(x,PR,label='Pressure Ratio')
ax.set_title('Pressure Ratio by Stage')
ax.set_ylabel('Pressure Ratio')
ax.set_xlabel('Stage')
ax.legend()
